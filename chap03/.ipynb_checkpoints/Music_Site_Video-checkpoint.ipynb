# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
page = urlopen('https://www.melon.com/chart/day/index.htm')
soup = BeautifulSoup(page, 'html.parser')
song_list = soup.find(class_='service_list_song').tbody.find_all('tr')
song_list
# Out:
# [<tr class="lst50" data-song-no="30948698" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="꽃 길 곡 선택" type="checkbox" value="30948698"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">1</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10147314');" title="꽃 길">
#  <img alt="꽃 길 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/47/314/10147314_500.jpg/melon/resize/120/quality/80/optimize" width="60">
#  <span class="bg_album_frame"></span>
#  </img></a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30948698');" title="꽃 길 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30948698);" title="꽃 길 재생">꽃 길</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('198094');" title="BIGBANG - 페이지 이동">BIGBANG</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('198094');" title="BIGBANG - 페이지 이동">BIGBANG</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10147314');" title="꽃 길 - 페이지 이동">꽃 길</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30948698" title="꽃 길 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30948698);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30948698');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30948698', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '30948698','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30948698')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30937275" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="별이 빛나는 밤 곡 선택" type="checkbox" value="30937275"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">2</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10145303');" title="Yellow Flower">
#  <img alt="Yellow Flower - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/45/303/10145303_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30937275');" title="별이 빛나는 밤 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30937275);" title="별이 빛나는 밤 재생">별이 빛나는 밤</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('750053');" title="마마무 - 페이지 이동">마마무</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('750053');" title="마마무 - 페이지 이동">마마무</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10145303');" title="Yellow Flower - 페이지 이동">Yellow Flower</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30937275" title="별이 빛나는 밤 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30937275);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30937275');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30937275', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30937275','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30937275')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30939452" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Jenga (Feat. Gaeko) 곡 선택" type="checkbox" value="30939452"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">3</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10145963');" title="바람">
#  <img alt="바람 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/45/963/10145963_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30939452');" title="Jenga (Feat. Gaeko) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30939452);" title="Jenga (Feat. Gaeko) 재생">Jenga (Feat. Gaeko)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10145963');" title="바람 - 페이지 이동">바람</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30939452" title="Jenga (Feat. Gaeko) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30939452);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30939452');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30939452', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30939452','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30939452')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30859584" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="사랑을 했다 (LOVE SCENARIO) 곡 선택" type="checkbox" value="30859584"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">4</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10132945');" title="Return">
#  <img alt="Return - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/32/945/10132945_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30859584');" title="사랑을 했다 (LOVE SCENARIO) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30859584);" title="사랑을 했다 (LOVE SCENARIO) 재생">사랑을 했다 (LOVE SCENARIO)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('895741');" title="iKON - 페이지 이동">iKON</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10132945');" title="Return - 페이지 이동">Return</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30859584" title="사랑을 했다 (LOVE SCENARIO) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30859584);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30859584');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30859584', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30859584','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30859584')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30816860" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="뿜뿜 곡 선택" type="checkbox" value="30816860"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">5</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT!">
#  <img alt="GREAT! - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/24/822/10124822_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30816860');" title="뿜뿜 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30816860);" title="뿜뿜 재생">뿜뿜</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1221596');" title="모모랜드 (MOMOLAND) - 페이지 이동">모모랜드 (MOMOLAND)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10124822');" title="GREAT! - 페이지 이동">GREAT!</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30816860" title="뿜뿜 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30816860);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30816860');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30816860', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30816860','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30816860')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30755375" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="그날처럼 곡 선택" type="checkbox" value="30755375"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">6</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼">
#  <img alt="그날처럼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/15/186/10115186_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30755375');" title="그날처럼 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30755375);" title="그날처럼 재생">그날처럼</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('829211');" title="장덕철 - 페이지 이동">장덕철</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10115186');" title="그날처럼 - 페이지 이동">그날처럼</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30755375" title="그날처럼 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30755375);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30755375');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30755375', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30755375','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30755375')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30939454" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="내가 더 나빠 곡 선택" type="checkbox" value="30939454"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">7</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10145963');" title="바람">
#  <img alt="바람 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/45/963/10145963_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30939454');" title="내가 더 나빠 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30939454);" title="내가 더 나빠 재생">내가 더 나빠</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10145963');" title="바람 - 페이지 이동">바람</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30939454" title="내가 더 나빠 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30939454);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30939454');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30939454', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30939454','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30939454')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30884950" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="그때 헤어지면 돼 곡 선택" type="checkbox" value="30884950"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">8</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼">
#  <img alt="그때 헤어지면 돼 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/37/574/10137574_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30884950');" title="그때 헤어지면 돼 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30884950);" title="그때 헤어지면 돼 재생">그때 헤어지면 돼</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('699632');" title="로이킴 - 페이지 이동">로이킴</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10137574');" title="그때 헤어지면 돼 - 페이지 이동">그때 헤어지면 돼</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30884950" title="그때 헤어지면 돼 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30884950);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30884950');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30884950', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30884950','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30884950')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30864993" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Bad Boy 곡 선택" type="checkbox" value="30864993"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">9</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage">
#  <img alt="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/34/032/10134032_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30864993');" title="Bad Boy 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30864993);" title="Bad Boy 재생">Bad Boy</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('780066');" title="Red Velvet (레드벨벳) - 페이지 이동">Red Velvet (레드벨벳)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10134032');" title="The Perfect Red Velvet - The 2nd Album Repackage - 페이지 이동">The Perfect Red Velvet - The 2nd Album Repackage</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30864993" title="Bad Boy 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30864993);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30864993');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30864993', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30864993','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30864993')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="8111603" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="HandClap 곡 선택" type="checkbox" value="8111603"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">10</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2675179');" title="Fitz and The Tantrums (Deluxe)">
#  <img alt="Fitz and The Tantrums (Deluxe) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/026/75/179/2675179_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('8111603');" title="HandClap 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',8111603);" title="HandClap 재생">HandClap</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('750471');" title="Fitz &amp; The Tantrums - 페이지 이동">Fitz &amp; The Tantrums</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('750471');" title="Fitz &amp; The Tantrums - 페이지 이동">Fitz &amp; The Tantrums</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('2675179');" title="Fitz and The Tantrums (Deluxe) - 페이지 이동">Fitz and The Tantrums (Deluxe)</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="8111603" title="HandClap 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',8111603);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('8111603');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '8111603', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '8111603','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','8111603')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30844118" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Roller Coaster 곡 선택" type="checkbox" value="30844118"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">11</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10129940');" title="Offset">
#  <img alt="Offset - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/29/940/10129940_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30844118');" title="Roller Coaster 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30844118);" title="Roller Coaster 재생">Roller Coaster</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('968265');" title="청하 - 페이지 이동">청하</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('968265');" title="청하 - 페이지 이동">청하</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10129940');" title="Offset - 페이지 이동">Offset</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30844118" title="Roller Coaster 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30844118);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30844118');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30844118', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30844118','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30844118')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30567963" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="Havana (Feat. Young Thug) 곡 선택" type="checkbox" value="30567963"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">12</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila">
#  <img alt="Camila - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/85/877/10085877_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30567963');" title="Havana (Feat. Young Thug) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30567963);" title="Havana (Feat. Young Thug) 재생">Havana (Feat. Young Thug)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('928017');" title="Camila Cabello - 페이지 이동">Camila Cabello</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10085877');" title="Camila - 페이지 이동">Camila</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30567963" title="Havana (Feat. Young Thug) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30567963);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30567963');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30567963', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30567963','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30567963')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30514366" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="선물 곡 선택" type="checkbox" value="30514366"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">13</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10078176');" title="Moonlight">
#  <img alt="Moonlight - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/78/176/10078176_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30514366');" title="선물 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30514366);" title="선물 재생">선물</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('839732');" title="멜로망스 - 페이지 이동">멜로망스</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10078176');" title="Moonlight - 페이지 이동">Moonlight</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30514366" title="선물 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30514366);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30514366');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30514366', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30514366','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30514366')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30939453" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="괜찮냐고 곡 선택" type="checkbox" value="30939453"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">14</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10145963');" title="바람">
#  <img alt="바람 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/45/963/10145963_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30939453');" title="괜찮냐고 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30939453);" title="괜찮냐고 재생">괜찮냐고</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('751611');" title="헤이즈 (Heize) - 페이지 이동">헤이즈 (Heize)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10145963');" title="바람 - 페이지 이동">바람</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30939453" title="괜찮냐고 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30939453);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30939453');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30939453', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30939453','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell disabled" disabled="disabled" onclick="melon.buy.popPhoneDecorate('0010000000000000','30939453')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst50" data-song-no="30086173" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="비행운 곡 선택" type="checkbox" value="30086173"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">15</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="1단계 상승">
#  <span class="bullet_icons rank_up"><span class="none">단계 상승</span></span>
#  <span class="up">1</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10013929');" title="LIFE IS BEAUTY FULL">
#  <img alt="LIFE IS BEAUTY FULL - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/13/929/10013929_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30086173');" title="비행운 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30086173);" title="비행운 재생">비행운</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('927668');" title="문문 (MoonMoon) - 페이지 이동">문문 (MoonMoon)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('927668');" title="문문 (MoonMoon) - 페이지 이동">문문 (MoonMoon)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10013929');" title="LIFE IS BEAUTY FULL - 페이지 이동">LIFE IS BEAUTY FULL</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30086173" title="비행운 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30086173);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30086173');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30086173', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video disabled" disabled="disabled" onclick="melon.link.goMvDetail('19041201', '30086173','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
# ...
#  </div></td>
#  </tr>, <tr class="lst100" data-song-no="30810765" id="lst100" style="display:none;">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="겨울소리 곡 선택" type="checkbox" value="30810765"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">96</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="2단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">2</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10123826');" title="겨울소리">
#  <img alt="겨울소리 - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/23/826/10123826_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30810765');" title="겨울소리 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30810765);" title="겨울소리 재생">겨울소리</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('1191');" title="박효신 - 페이지 이동">박효신</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1191');" title="박효신 - 페이지 이동">박효신</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10123826');" title="겨울소리 - 페이지 이동">겨울소리</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30810765" title="겨울소리 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30810765);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30810765');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30810765', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30810765','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30810765')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst100" data-song-no="30939515" id="lst100" style="display:none;">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="She`s gone 곡 선택" type="checkbox" value="30939515"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">97</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="2단계 하락">
#  <span class="bullet_icons rank_down"><span class="none">단계 하락</span></span>
#  <span class="down">2</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10145978');" title="Big wave">
#  <img alt="Big wave - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/45/978/10145978_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30939515');" title="She`s gone 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30939515);" title="She`s gone 재생">She`s gone</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('648052');" title="정일훈 - 페이지 이동">정일훈</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('648052');" title="정일훈 - 페이지 이동">정일훈</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10145978');" title="Big wave - 페이지 이동">Big wave</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30939515" title="She`s gone 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30939515);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30939515');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30939515', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30939515','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30939515')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst100" data-song-no="30568337" id="lst100" style="display:none;">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="활활 (Burn It Up) 곡 선택" type="checkbox" value="30568337"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">98</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10085951');" title="1X1=1(TO BE ONE)">
#  <img alt="1X1=1(TO BE ONE) - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/100/85/951/10085951_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30568337');" title="활활 (Burn It Up) 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30568337);" title="활활 (Burn It Up) 재생">활활 (Burn It Up)</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('1865973');" title="Wanna One (워너원) - 페이지 이동">Wanna One (워너원)</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1865973');" title="Wanna One (워너원) - 페이지 이동">Wanna One (워너원)</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10085951');" title="1X1=1(TO BE ONE) - 페이지 이동">1X1=1(TO BE ONE)</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30568337" title="활활 (Burn It Up) 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30568337);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30568337');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30568337', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30568337','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30568337')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst100" data-song-no="30661885" id="lst100" style="display:none;">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="WHERE YOU AT 곡 선택" type="checkbox" value="30661885"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">99</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 진입">
#  <span class="bullet_icons rank_new"><span class="none">순위 진입</span></span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('10100941');" title="W, HERE">
#  <img alt="W, HERE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/101/00/941/10100941_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('30661885');" title="WHERE YOU AT 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',30661885);" title="WHERE YOU AT 재생">WHERE YOU AT</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('1816966');" title="뉴이스트 W - 페이지 이동">뉴이스트 W</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('1816966');" title="뉴이스트 W - 페이지 이동">뉴이스트 W</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('10100941');" title="W, HERE - 페이지 이동">W, HERE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="30661885" title="WHERE YOU AT 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',30661885);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('30661885');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '30661885', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '30661885','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1110000000000000','30661885')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>, <tr class="lst100" data-song-no="8086947" id="lst100" style="display:none;">
#  <td><div class="wrap t_right"><input class="input_check " name="input_check" title="한숨 곡 선택" type="checkbox" value="8086947"/></div></td>
#  <td><div class="wrap t_center"><span class="rank ">100</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 진입">
#  <span class="bullet_icons rank_new"><span class="none">순위 진입</span></span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('2671866');" title="SEOULITE">
#  <img alt="SEOULITE - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="http://cdnimg.melon.co.kr/cm/album/images/026/71/866/2671866_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('8086947');" title="한숨 곡정보"><span class="none">곡정보</span></a>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank01"><span>
#  <a href="javascript:melon.play.playSong('19041201',8086947);" title="한숨 재생">한숨</a>
#  </span></div><br/>
#  <div class="ellipsis rank02">
#  <a href="javascript:melon.link.goArtistDetail('646171');" title="이하이 - 페이지 이동">이하이</a><span class="checkEllipsis" style="display:none"><a href="javascript:melon.link.goArtistDetail('646171');" title="이하이 - 페이지 이동">이하이</a></span>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <div class="wrap_song_info">
#  <div class="ellipsis rank03">
#  <a href="javascript:melon.link.goAlbumDetail('2671866');" title="SEOULITE - 페이지 이동">SEOULITE</a>
#  </div>
#  </div>
#  </div></td>
#  <td><div class="wrap">
#  <button class="button_etc like" data-song-menuid="19041201" data-song-no="8086947" title="한숨 좋아요" type="button">
#  <span class="odd_span">좋아요</span>
#  <span class="cnt">
#  <span class="none">총건수</span>
#  												0
#  											</span>
#  </button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons play " onclick="melon.play.playSong('19041201',8086947);" title="듣기" type="button"><span class="none">듣기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons scrap " onclick="melon.play.addPlayList('8086947');" title="담기" type="button"><span class="none">담기</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons download " onclick="melon.buy.goBuyProduct('frm', '8086947', '3C0001', '','0', '19041201');" title="다운로드" type="button"><span class="none">다운로드</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons video " onclick="melon.link.goMvDetail('19041201', '8086947','song');" title="뮤직비디오" type="button"><span class="none">뮤직비디오</span></button>
#  </div></td>
#  <td><div class="wrap t_center">
#  <button class="button_icons bell " onclick="melon.buy.popPhoneDecorate('1100000000000000','8086947')" title="링/벨" type="button"><span class="none">링/벨</span></button>
#  </div></td>
#  </tr>]

# %%
daily_song_chart = []

for song in song_list:
    rank = song.find(class_ = 'rank').text
    updown = song.find(class_ = 'rank_wrap').text.split('\n')[2]    
    title = song.find('div', class_='rank01').a.text
    singer = song.find('div', class_='rank02').a.text
    album_name = song.find(class_='rank03').a.text

    song_num = song['data-song-no']
    print(song_num)
  #  url = 'https://www.melon.com/song/detail.htm?songId=' + song_num
  #  song_page = urlopen(url)
  #  soup = BeautifulSoup(song_page, 'html.parser')
  #  release_date = soup.find(class_ = 'list').find_all('dd')[1].text

    if updown == "" :
        updown = 0
        
    daily_song_chart.append([int(rank), abs(int(updown)), title, singer, album_name]) #, release_date])
    
    print('순위 : ', rank)
    print('변동폭 : ', updown)
    print('제목 : ', title)
    print('가수 : ', singer)
    print('앨범명 : ', album_name)
   # print('발매일 : ', release_date)
    print()
# Out:
# 30948698
# 순위 :  1
# 변동폭 :  0
# 제목 :  꽃 길
# 가수 :  BIGBANG
# 앨범명 :  꽃 길
#
# 30937275
# 순위 :  2
# 변동폭 :  0
# 제목 :  별이 빛나는 밤
# 가수 :  마마무
# 앨범명 :  Yellow Flower
#
# 30939452
# 순위 :  3
# 변동폭 :  0
# 제목 :  Jenga (Feat. Gaeko)
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
#
# 30859584
# 순위 :  4
# 변동폭 :  0
# 제목 :  사랑을 했다 (LOVE SCENARIO)
# 가수 :  iKON
# 앨범명 :  Return
#
# 30816860
# 순위 :  5
# 변동폭 :  0
# 제목 :  뿜뿜
# 가수 :  모모랜드 (MOMOLAND)
# 앨범명 :  GREAT!
#
# 30755375
# 순위 :  6
# 변동폭 :  0
# 제목 :  그날처럼
# 가수 :  장덕철
# 앨범명 :  그날처럼
#
# 30939454
# 순위 :  7
# 변동폭 :  0
# 제목 :  내가 더 나빠
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
#
# 30884950
# 순위 :  8
# 변동폭 :  0
# 제목 :  그때 헤어지면 돼
# 가수 :  로이킴
# 앨범명 :  그때 헤어지면 돼
#
# 30864993
# 순위 :  9
# 변동폭 :  0
# 제목 :  Bad Boy
# 가수 :  Red Velvet (레드벨벳)
# 앨범명 :  The Perfect Red Velvet - The 2nd Album Repackage
#
# 8111603
# 순위 :  10
# 변동폭 :  0
# 제목 :  HandClap
# 가수 :  Fitz & The Tantrums
# 앨범명 :  Fitz and The Tantrums (Deluxe)
#
# 30844118
# 순위 :  11
# 변동폭 :  0
# 제목 :  Roller Coaster
# 가수 :  청하
# 앨범명 :  Offset
#
# 30567963
# 순위 :  12
# 변동폭 :  0
# 제목 :  Havana (Feat. Young Thug)
# 가수 :  Camila Cabello
# 앨범명 :  Camila
#
# 30514366
# 순위 :  13
# 변동폭 :  0
# 제목 :  선물
# 가수 :  멜로망스
# 앨범명 :  Moonlight
#
# 30939453
# 순위 :  14
# 변동폭 :  0
# 제목 :  괜찮냐고
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
#
# 30086173
# 순위 :  15
# 변동폭 :  1
# 제목 :  비행운
# 가수 :  문문 (MoonMoon)
# 앨범명 :  LIFE IS BEAUTY FULL
#
# 30930312
# 순위 :  16
# 변동폭 :  1
# 제목 :  약속해요 (I.P.U.)
# 가수 :  Wanna One (워너원)
# 앨범명 :  약속해요 (I.P.U.) - Special Theme Track
#
# 30951305
# 순위 :  17
# 변동폭 :  0
# 제목 :  나타나줘 (Feat. 박재범)
# 가수 :  로꼬
# 앨범명 :  나타나줘
#
# 30877002
# 순위 :  18
# 변동폭 :  1
# 제목 :  눈사람
# 가수 :  정승환
# 앨범명 :  그리고 봄
#
# 30721801
# 순위 :  19
# 변동폭 :  0
# 제목 :  My Way
# 가수 :  이수 (엠씨 더 맥스)
# 앨범명 :  돈꽃 OST Part.1
#
# 30806580
# 순위 :  20
# 변동폭 :  2
# 제목 :  instagram
# 가수 :  DEAN
# 앨범명 :  instagram
#
# 30838076
# 순위 :  21
# 변동폭 :  1
# 제목 :  주인공
# 가수 :  선미
# 앨범명 :  주인공
#
# 30659630
# 순위 :  22
# 변동폭 :  1
# 제목 :  밤이 되니까
# 가수 :  펀치 (Punch)
# 앨범명 :  밤이 되니까
#
# 30829858
# 순위 :  23
# 변동폭 :  1
# 제목 :  #첫사랑
# 가수 :  볼빨간사춘기
# 앨범명 :  #첫사랑
#
# 30637776
# 순위 :  24
# 변동폭 :  1
# 제목 :  이 별
# 가수 :  길구봉구
# 앨범명 :  Star
#
# 30849733
# 순위 :  25
# 변동폭 :  1
# 제목 :  You
# 가수 :  멜로망스
# 앨범명 :  투유 프로젝트 - 슈가맨2 Part.2
#
# 30669593
# 순위 :  26
# 변동폭 :  1
# 제목 :  가을 안부
# 가수 :  먼데이 키즈
# 앨범명 :  가을 안부
#
# 30725482
# 순위 :  27
# 변동폭 :  3
# 제목 :  Beautiful
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
#
# 30781481
# 순위 :  28
# 변동폭 :  1
# 제목 :  Heart Shaker
# 가수 :  TWICE (트와이스)
# 앨범명 :  Merry & Happy
#
# 30486509
# 순위 :  29
# 변동폭 :  1
# 제목 :  좋니
# 가수 :  윤종신
# 앨범명 :  LISTEN 010 좋니
#
# 30690674
# 순위 :  30
# 변동폭 :  1
# 제목 :  눈 떠보니 이별이더라
# 가수 :  포맨
# 앨범명 :  REMEMBER ME
#
# 30550388
# 순위 :  31
# 변동폭 :  0
# 제목 :  all of my life
# 가수 :  박원
# 앨범명 :  0M
#
# 30672529
# 순위 :  32
# 변동폭 :  2
# 제목 :  그리워하다
# 가수 :  비투비
# 앨범명 :  Brother Act.
#
# 30492279
# 순위 :  33
# 변동폭 :  7
# 제목 :  비도 오고 그래서 (Feat. 신용재)
# 가수 :  헤이즈 (Heize)
# 앨범명 :  /// (너 먹구름 비)
#
# 30188113
# 순위 :  34
# 변동폭 :  2
# 제목 :  Shape of You
# 가수 :  Ed Sheeran
# 앨범명 :  ÷ (Deluxe)
#
# 30637982
# 순위 :  35
# 변동폭 :  2
# 제목 :  DNA
# 가수 :  방탄소년단
# 앨범명 :  LOVE YOURSELF 承 `Her`
#
# 30568338
# 순위 :  36
# 변동폭 :  2
# 제목 :  에너제틱 (Energetic)
# 가수 :  Wanna One (워너원)
# 앨범명 :  1X1=1(TO BE ONE)
#
# 30314784
# 순위 :  37
# 변동폭 :  0
# 제목 :  밤편지
# 가수 :  아이유
# 앨범명 :  밤편지
#
# 30613202
# 순위 :  38
# 변동폭 :  2
# 제목 :  시차 (We Are) (Feat. 로꼬 & GRAY)
# 가수 :  우원재
# 앨범명 :  시차 (We Are)
#
# 30851703
# 순위 :  39
# 변동폭 :  4
# 제목 :  다른사람을 사랑하고 있어
# 가수 :  수지 (SUZY)
# 앨범명 :  Faces of Love
#
# 30700708
# 순위 :  40
# 변동폭 :  2
# 제목 :  LIKEY
# 가수 :  TWICE (트와이스)
# 앨범명 :  twicetagram
#
# 30757693
# 순위 :  41
# 변동폭 :  2
# 제목 :  기억의 빈자리
# 가수 :  나얼
# 앨범명 :  기억의 빈자리
#
# 30244931
# 순위 :  42
# 변동폭 :  0
# 제목 :  봄날
# 가수 :  방탄소년단
# 앨범명 :  YOU NEVER WALK ALONE
#
# 30729198
# 순위 :  43
# 변동폭 :  0
# 제목 :  좋아
# 가수 :  민서
# 앨범명 :  2017 월간 윤종신 11월호
#
# 30736437
# 순위 :  44
# 변동폭 :  3
# 제목 :  피카부 (Peek-A-Boo)
# 가수 :  Red Velvet (레드벨벳)
# 앨범명 :  Perfect Velvet - The 2nd Album
#
# 30657307
# 순위 :  45
# 변동폭 :  0
# 제목 :  썸 탈꺼야
# 가수 :  볼빨간사춘기
# 앨범명 :  Red Diary Page.1
#
# 30833270
# 순위 :  46
# 변동폭 :  2
# 제목 :  답장
# 가수 :  김동률
# 앨범명 :  답장
#
# 30380953
# 순위 :  47
# 변동폭 :  1
# 제목 :  There`s Nothing Holdin` Me Back
# 가수 :  Shawn Mendes
# 앨범명 :  Illuminate (New Deluxe Ver.)
#
# 30099927
# 순위 :  48
# 변동폭 :  1
# 제목 :  노력
# 가수 :  박원
# 앨범명 :  1/24
#
# 30753213
# 순위 :  49
# 변동폭 :  1
# 제목 :  바보야
# 가수 :  허각
# 앨범명 :  바보야
#
# 30709103
# 순위 :  50
# 변동폭 :  1
# 제목 :  그때의 나, 그때의 우리
# 가수 :  어반자카파
# 앨범명 :  그때의 나, 그때의 우리
#
# 30190630
# 순위 :  51
# 변동폭 :  1
# 제목 :  첫눈처럼 너에게 가겠다
# 가수 :  에일리
# 앨범명 :  도깨비 OST Part.9
#
# 30667988
# 순위 :  52
# 변동폭 :  1
# 제목 :  짙어져
# 가수 :  멜로망스
# 앨범명 :  Yellow OST Part.2
#
# 30512671
# 순위 :  53
# 변동폭 :  1
# 제목 :  빨간 맛 (Red Flavor)
# 가수 :  Red Velvet (레드벨벳)
# 앨범명 :  The Red Summer - Summer Mini Album
#
# 30481578
# 순위 :  54
# 변동폭 :  0
# 제목 :  마지막처럼
# 가수 :  BLACKPINK
# 앨범명 :  마지막처럼
#
# 30383758
# 순위 :  55
# 변동폭 :  2
# 제목 :  Lonely (Feat. 태연)
# 가수 :  종현 (JONGHYUN)
# 앨범명 :  종현 소품집 `이야기 Op.2`
#
# 30393293
# 순위 :  56
# 변동폭 :  1
# 제목 :  Thunder
# 가수 :  Imagine Dragons
# 앨범명 :  Evolve
#
# 4383833
# 순위 :  57
# 변동폭 :  0
# 제목 :  바람이 불었으면 좋겠어
# 가수 :  길구봉구
# 앨범명 :  바람이 불었으면 좋겠어
#
# 30587846
# 순위 :  58
# 변동폭 :  2
# 제목 :  가시나
# 가수 :  선미
# 앨범명 :  SUNMI SPECIAL EDITION `가시나`
#
# 30688500
# 순위 :  59
# 변동폭 :  0
# 제목 :  연애소설 (Feat. 아이유)
# 가수 :  에픽하이 (EPIK HIGH)
# 앨범명 :  WE`VE DONE SOMETHING WONDERFUL
#
# 30935467
# 순위 :  60
# 변동폭 :  0
# 제목 :  별 바람 꽃 태양
# 가수 :  마마무
# 앨범명 :  Yellow Flower
#
# 30939455
# 순위 :  61
# 변동폭 :  3
# 제목 :  잘 살길 바래 (With. DAVII)
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
#
# 30859636
# 순위 :  62
# 변동폭 :  0
# 제목 :  너 없는 시간들
# 가수 :  다비치
# 앨범명 :  &10
#
# 30657311
# 순위 :  63
# 변동폭 :  0
# 제목 :  나의 사춘기에게
# 가수 :  볼빨간사춘기
# 앨범명 :  Red Diary Page.1
#
# 30806536
# 순위 :  64
# 변동폭 :  3
# 제목 :  Universe
# 가수 :  EXO
# 앨범명 :  Universe - 겨울 스페셜 앨범, 2017
#
# 30809895
# 순위 :  65
# 변동폭 :  1
# 제목 :  미안해
# 가수 :  양다일
# 앨범명 :  inside
#
# 30341745
# 순위 :  66
# 변동폭 :  0
# 제목 :  REALLY REALLY
# 가수 :  WINNER
# 앨범명 :  FATE NUMBER FOR
#
# 30889749
# 순위 :  67
# 변동폭 :  1
# 제목 :  애쓰지 마요
# 가수 :  박보람
# 앨범명 :  애쓰지 마요
#
# 30725483
# 순위 :  68
# 변동폭 :  3
# 제목 :  갖고 싶어
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
#
# 8287788
# 순위 :  69
# 변동폭 :  0
# 제목 :  Closer (Feat. Halsey)
# 가수 :  The Chainsmokers
# 앨범명 :  Collage EP
#
# 30637988
# 순위 :  70
# 변동폭 :  1
# 제목 :  고민보다 Go
# 가수 :  방탄소년단
# 앨범명 :  LOVE YOURSELF 承 `Her`
#
# 30878838
# 순위 :  71
# 변동폭 :  1
# 제목 :  고맙다
# 가수 :  세븐틴
# 앨범명 :  SEVENTEEN SPECIAL ALBUM `DIRECTOR`S CUT`
#
# 30948892
# 순위 :  72
# 변동폭 :  5
# 제목 :  Action! (Feat. GRAY)
# 가수 :  DPR LIVE
# 앨범명 :  Action!
#
# 30879719
# 순위 :  73
# 변동폭 :  1
# 제목 :  오늘밤도
# 가수 :  펀치 (Punch)
# 앨범명 :  오늘밤도
#
# 30688990
# 순위 :  74
# 변동폭 :  1
# 제목 :  그 사람을 아나요
# 가수 :  임창정
# 앨범명 :  그 사람을 아나요
#
# 30939457
# 순위 :  75
# 변동폭 :  3
# 제목 :  MIANHAE
# 가수 :  헤이즈 (Heize)
# 앨범명 :  바람
#
# 30529996
# 순위 :  76
# 변동폭 :  1
# 제목 :  Ko Ko Bop
# 가수 :  EXO
# 앨범명 :  THE WAR - The 4th Album
#
# 30827192
# 순위 :  77
# 변동폭 :  1
# 제목 :  비밀정원
# 가수 :  오마이걸
# 앨범명 :  비밀정원
#
# 30637987
# 순위 :  78
# 변동폭 :  1
# 제목 :  MIC Drop
# 가수 :  방탄소년단
# 앨범명 :  LOVE YOURSELF 承 `Her`
#
# 30929917
# 순위 :  79
# 변동폭 :  3
# 제목 :  고무줄다리기 (Rubber Band)
# 가수 :  iKON
# 앨범명 :  고무줄다리기 (Rubber Band)
#
# 30945696
# 순위 :  80
# 변동폭 :  3
# 제목 :  Look
# 가수 :  GOT7 (갓세븐)
# 앨범명 :  Eyes On You
#
# 30467550
# 순위 :  81
# 변동폭 :  1
# 제목 :  매일 듣는 노래 (A Daily Song)
# 가수 :  황치열
# 앨범명 :  Be ordinary
#
# 3753304
# 순위 :  82
# 변동폭 :  14
# 제목 :  벚꽃 엔딩
# 가수 :  버스커 버스커
# 앨범명 :  버스커 버스커 1집
#
# 30616684
# 순위 :  83
# 변동폭 :  2
# 제목 :  Power
# 가수 :  EXO
# 앨범명 :  The Power of Music - The 4th Album Repackage
#
# 30902280
# 순위 :  84
# 변동폭 :  1
# 제목 :  네가 없는 곳
# 가수 :  양요섭
# 앨범명 :  YANG YOSEOP 2ND MINI ALBUM `白`
#
# 30945823
# 순위 :  85
# 변동폭 :  1
# 제목 :  My Blossom
# 가수 :  소유 (SOYOU)
# 앨범명 :  My Blossom
#
# 91299
# 순위 :  86
# 변동폭 :  4
# 제목 :  빛 (Hope)
# 가수 :  H.O.T.
# 앨범명 :  H.O.T 3
#
# 30378156
# 순위 :  87
# 변동폭 :  2
# 제목 :  팔레트 (Feat. G-DRAGON)
# 가수 :  아이유
# 앨범명 :  Palette
#
# 30725484
# 순위 :  88
# 변동폭 :  1
# 제목 :  Twilight
# 가수 :  Wanna One (워너원)
# 앨범명 :  1-1=0 (NOTHING WITHOUT YOU)
#
# 30029173
# 순위 :  89
# 변동폭 :  0
# 제목 :  피 땀 눈물
# 가수 :  방탄소년단
# 앨범명 :  WINGS
#
# 30942260
# 순위 :  90
# 변동폭 :  2
# 제목 :  실례해도 될까요
# 가수 :  장재인
# 앨범명 :  LISTEN 020 실례해도 될까요
#
# 8033528
# 순위 :  91
# 변동폭 :  1
# 제목 :  어디에도
# 가수 :  엠씨더맥스
# 앨범명 :  pathos
#
# 30899960
# 순위 :  92
# 변동폭 :  6
# 제목 :  후유증
# 가수 :  민경훈
# 앨범명 :  후유증
#
# 30902271
# 순위 :  93
# 변동폭 :  1
# 제목 :  비가 온다
# 가수 :  정승환
# 앨범명 :  그리고 봄
#
# 30657308
# 순위 :  94
# 변동폭 :  3
# 제목 :  Blue
# 가수 :  볼빨간사춘기
# 앨범명 :  Red Diary Page.1
#
# 4032981
# 순위 :  95
# 변동폭 :  4
# 제목 :  여보세요
# 가수 :  NU`EST
# 앨범명 :  THE SECOND MINI ALBUM `여보세요`
#
# 30810765
# 순위 :  96
# 변동폭 :  2
# 제목 :  겨울소리
# 가수 :  박효신
# 앨범명 :  겨울소리
#
# 30939515
# 순위 :  97
# 변동폭 :  2
# 제목 :  She`s gone
# 가수 :  정일훈
# 앨범명 :  Big wave
#
# 30568337
# 순위 :  98
# 변동폭 :  0
# 제목 :  활활 (Burn It Up)
# 가수 :  Wanna One (워너원)
# 앨범명 :  1X1=1(TO BE ONE)
#
# 30661885
# 순위 :  99
# 변동폭 :  0
# 제목 :  WHERE YOU AT
# 가수 :  뉴이스트 W
# 앨범명 :  W, HERE
#
# 8086947
# 순위 :  100
# 변동폭 :  0
# 제목 :  한숨
# 가수 :  이하이
# 앨범명 :  SEOULITE

# %%
page = urlopen('https://www.melon.com/chart/vdo/index.htm')
soup = BeautifulSoup(page, 'html.parser')
video_list = soup.find(class_='d_video_list').find_all('li', class_='lst50')
video_list += soup.find(class_='d_video_list').find_all('li', class_='lst100')

# %%
video_infos = []

for video in video_list:
    info = video.find(class_ = 'entry')
    
    ranking = video.find(class_='wrap_rank').span.text
    artist_name = video.find(class_='info').find(class_="artist_name").text
    title = info.find(class_='info').a.text.replace("[MV]","")
    rating = video.find(class_='bullet_icons').find(class_='none').text.replace("세 이상 이용가능", "").strip('"')

    if rating.split(" ")[0] == '단계' or rating.split(" ")[0] == '순위' or rating == '전체 이용가능':
        rating = 0
    
    video_infos.append([int(ranking), artist_name, title, int(rating)])

# %%
video_infos
# Out:
# [[1, '헤이즈 (Heize)', '[Special Clip] 헤이즈 (Heize) - 내가 더 나빠', 0],
#  [2, '마마무', '별이 빛나는 밤', 15],
#  [3, '모모랜드 (MOMOLAND)', '뿜뿜', 12],
#  [4, 'Wanna One (워너원)', '약속해요 (I.P.U.)', 0],
#  [5, 'DPR LIVE', '[썰렘코드] DPR LIVE - Action! (Feat. GRAY)', 0],
#  [6, '헤이즈 (Heize)', 'Jenga (Feat. Gaeko)', 15],
#  [7, 'GOT7 (갓세븐)', 'Look', 12],
#  [8, 'NCT 127', 'TOUCH', 12],
#  [9, 'NCT U', 'BOSS', 15],
#  [10, 'Red Velvet (레드벨벳)', 'Bad Boy', 12],
#  [11, 'Bruno Mars', 'Finesse (Remix) (Feat. Cardi B)', 15],
#  [12, '핑크퐁', '상어 가족', 0],
#  [13, '에이프릴 (APRIL)', '파랑새', 12],
#  [14, 'TWICE (트와이스)', 'Heart Shaker', 12],
#  [15, '헤이즈 (Heize)', 'MIANHAE', 15],
#  [16, 'iKON', '사랑을 했다 (LOVE SCENARIO)', 12],
#  [17, '마마무', '[유희열의 스케치북] 별이 빛나는 밤', 0],
#  [18, '최예근', '미안하다는 말 (Original Ver.)', 12],
#  [19, '청하', 'Roller Coaster', 12],
#  [20, 'HOYA (호야)', 'Angel', 15],
#  [21, 'TWICE (트와이스)', 'LIKEY', 12],
#  [22, '마마무', '별 바람 꽃 태양', 12],
#  [23, 'Junoflo (주노플로)', 'Grapevine (포도주) (Feat. 박재범)', 12],
#  [24, '헤이즈 (Heize)', '내가 더 나빠', 12],
#  [25, 'NCT DREAM', 'GO', 12],
#  [26, 'MXM (BRANDNEWBOYS)', '식어버린 온도 (GONE COLD)', 12],
#  [27, '해빈 (구구단)', '길에서', 0],
#  [28, '마마무', '[유희열의 스케치북] 리듬 속의 그 춤을 + 흐린 기억속의 그대 + 황홀한 고백 + 깊은 밤을 날아서', 0],
#  [29, 'NCT U', 'Baby Don`t Stop', 12],
#  [30, '포레스텔라', 'You are my star', 0],
#  [31, '방탄소년단', 'DNA', 0],
#  [32, '김영철', '안되나용 (Feat. 휘성 (Realslow))', 0],
#  [33, '선미', '주인공', 12],
#  [34, '핑크퐁', '펭귄 댄스', 0],
#  [35, 'Imagine Dragons', '이제는 스마트폰 광고까지 접수한 상상용', 0],
#  [36, 'MXM (BRANDNEWBOYS)', 'MXM 식어버린 온도(GONE COLD)’ 어쿠스틱 라이브 클립 공개', 0],
#  [37, '핑크퐁', '동물의 왕 사자', 0],
#  [38, '스컬', '오래된 엘피 (Feat. 매드클라운, 허각)', 15],
#  [39, '셀럽파이브', '셀럽파이브 (셀럽이 되고 싶어)', 12],
#  [40, 'BLACKPINK', '마지막처럼', 12],
#  [41, 'Red Velvet (레드벨벳)', '피카부 (Peek-A-Boo)', 15],
#  [42, 'Wanna One (워너원)', '에너제틱 (Energetic)', 0],
#  [43, 'Wanna One (워너원)', '약속해요 (I.P.U.) (Teaser)', 0],
#  [44, '로꼬', "로꼬 '나타나줘 (Feat. 박재범)' 라이브 클립 메이킹 영상", 0],
#  [45, '핑크퐁', '쾌지나 칭칭 나네', 0],
#  [46, '아이유', "[스타DJ 라디오 스페셜] 연말특집 메들리 '별별쏭'", 0],
#  [47, '로꼬', "로꼬, '나타나줘 (Feat. 박재범)' 오늘 오후 6시 공개", 0],
#  [48, 'V', '죽어도 너야', 0],
#  [49, 'Wanna One (워너원)', 'Beautiful (Performance Ver.)', 0],
#  [50, 'TWICE (트와이스)', 'Candy Pop', 12],
#  [51, '오마이걸', '비밀정원', 12],
#  [52, 'Red Velvet (레드벨벳)', '빨간 맛 (Red Flavor)', 12],
#  [53, '강호동', '복을 발로 차버렸어 (I kicked my luck off)', 12],
#  [54, '정일훈', 'She`s gone', 15],
#  [55, '로이킴', '그때 헤어지면 돼', 0],
#  [56, '김재환', '[불후의 명곡] 잊을게', 0],
#  [57, '모모랜드 (MOMOLAND)', '[쇼챔피언] 뿜뿜', 0],
#  [58, 'CLC (씨엘씨)', 'BLACK DRESS', 15],
#  [59, 'Wanna One (워너원)', 'Beautiful (Performance Ver.) (Teaser)', 0],
#  [60,
#   '여자친구 (GFRIEND)',
#   '여자친구 GFRIEND - 시간을 달려서 (ROUGH) Dance Practice ver.',
#   0],
#  [61, '우주소녀', '꿈꾸는 마음으로', 12],
#  [62, 'TWICE (트와이스)', 'TT', 12],
#  [63, 'Wanna One (워너원)', 'Beautiful (Movie Ver.)', 15],
#  [64, '티디', '봄나들이', 0],
#  [65, '소향', '[복면가왕] 안아줘 (흥부자댁)', 0],
#  [66, '테이', '[불후의 명곡] 이별 이야기', 0],
#  [67, '허각', "허각 '바보야' 뮤비 주인공 옹성우 인터뷰", 0],
#  [68, '방탄소년단', '불타오르네 (FIRE)', 12],
#  [69, '장재인', '실례해도 될까요', 0],
#  [70, '소녀온탑', '같은 곳에서', 12],
#  [71, '핑크퐁', '바닷속에는', 0],
#  [72, 'NCT U', '[쇼챔피언] BOSS', 0],
#  [73, '정동하', '[불후의 명곡] 난 아직 모르잖아요', 0],
#  [74, '선미', '가시나', 15],
#  [75, '정승환', '비가 온다', 0],
#  [76, '정승환', '눈사람', 0],
#  [77, '헤이즈 (Heize)', '괜찮냐고 (Teaser)', 12],
#  [78, '김민호', '살아있는 공룡', 0],
#  [79, 'Camila Cabello', 'Havana (Feat. Young Thug)', 15],
#  [80, '조우찬', 'OGZ (PROD. GroovyRoom)', 12],
#  [81, 'NU`EST', "NU'EST 4th Mini Album `Q is.` M/V 2nd Teaser", 0],
#  [82, '마마무', '[유희열의 스케치북] 마마무 토크쇼', 0],
#  [83, '핑크퐁', '아기 동물들', 0],
#  [84, '김성규', 'True Love', 12],
#  [85, 'MXM (BRANDNEWBOYS)', "MXM 더블 싱글 'REMATCH' 미리듣기 공개", 0],
#  [86, '민경훈', '후유증', 15],
#  [87, '수지 (SUZY)', '잘자 내 몫까지 (With 이루마)', 12],
#  [88, '스컬', '이별을 했는데 (Feat. SUPERBEE, 조희철)', 15],
#  [89, '싸이 (PSY)', 'New Face', 15],
#  [90, '헨리 (HENRY)', '사랑 좀 하고 싶어 (Real Love)', 12],
#  [91, 'BIGBANG', 'FANTASTIC BABY', 0],
#  [92, 'TWICE (트와이스)', 'KNOCK KNOCK', 12],
#  [93, 'TWICE (트와이스)', 'One More Time', 12],
#  [94, 'TWICE (트와이스)', 'SIGNAL', 12],
#  [95, '마마무', '칠해줘', 15],
#  [96, 'iKON', '고무줄다리기 (Rubber Band) DANCE PRACTICE VIDEO (MOVING VER.)', 0],
#  [97, '수지 (SUZY)', 'SObeR', 15],
#  [98, 'BLACKPINK', '불장난', 12],
#  [99,
#   'MXM (BRANDNEWBOYS)',
#   '식어버린 온도 (GONE COLD) (LIMYOUNGMIN Ver.) (Teaser)',
#   0],
#  [100, 'TWICE (트와이스)', 'CHEER UP', 12]]

# %%
import pandas as pd

video_frame = pd.DataFrame(video_infos, columns=['멜론_동영상_랭킹', '멜론_아티스트', '멜론_제목', '멜론_등급'])

# %%
video_frame.head()
# Out:
#    멜론_동영상_랭킹          멜론_아티스트                                   멜론_제목  멜론_등급
# 0          1      헤이즈 (Heize)    [Special Clip] 헤이즈 (Heize) - 내가 더 나빠      0
# 1          2              마마무                                별이 빛나는 밤     15
# 2          3  모모랜드 (MOMOLAND)                                      뿜뿜     12
# 3          4  Wanna One (워너원)                           약속해요 (I.P.U.)      0
# 4          5         DPR LIVE  [썰렘코드] DPR LIVE - Action! (Feat. GRAY)      0

# %%
video_frame.to_csv('../../data/melon_video.csv', sep=',', encoding='utf-8', index=False)

# %%
load_video = pd.read_csv('../../data/melon_video.csv', thousands=',', encoding='utf-8')
load_video.head()
# Out:
#    멜론_동영상_랭킹          멜론_아티스트                                   멜론_제목  멜론_등급
# 0          1      헤이즈 (Heize)    [Special Clip] 헤이즈 (Heize) - 내가 더 나빠      0
# 1          2              마마무                                별이 빛나는 밤     15
# 2          3  모모랜드 (MOMOLAND)                                      뿜뿜     12
# 3          4  Wanna One (워너원)                           약속해요 (I.P.U.)      0
# 4          5         DPR LIVE  [썰렘코드] DPR LIVE - Action! (Feat. GRAY)      0

# %%
songs_frame = pd.DataFrame(daily_song_chart, columns=['랭킹', '멜론_등락', '멜론_제목', '멜론_가수', '멜론_앨범'])
songs_frame.head()
# Out:
#    랭킹  멜론_등락                   멜론_제목            멜론_가수          멜론_앨범
# 0   1      0                     꽃 길          BIGBANG            꽃 길
# 1   2      0                별이 빛나는 밤              마마무  Yellow Flower
# 2   3      0     Jenga (Feat. Gaeko)      헤이즈 (Heize)             바람
# 3   4      0  사랑을 했다 (LOVE SCENARIO)             iKON         Return
# 4   5      0                      뿜뿜  모모랜드 (MOMOLAND)         GREAT!

# %%
data_result = pd.merge(songs_frame, video_frame, on='멜론_제목')
data_result.head()
# Out:
#    랭킹  멜론_등락                   멜론_제목            멜론_가수          멜론_앨범  \
# 0   2      0                별이 빛나는 밤              마마무  Yellow Flower
# 1   3      0     Jenga (Feat. Gaeko)      헤이즈 (Heize)             바람
# 2   4      0  사랑을 했다 (LOVE SCENARIO)             iKON         Return
# 3   5      0                      뿜뿜  모모랜드 (MOMOLAND)         GREAT!
# 4   7      0                 내가 더 나빠      헤이즈 (Heize)             바람
#
#    멜론_동영상_랭킹          멜론_아티스트  멜론_등급
# 0          2              마마무     15
# 1          6      헤이즈 (Heize)     15
# 2         16             iKON     12
# 3          3  모모랜드 (MOMOLAND)     12
# 4         24      헤이즈 (Heize)     12

# %%
import numpy as np

np.corrcoef(data_result['랭킹'], data_result['멜론_동영상_랭킹'])
# Out:
# array([[1.        , 0.47597305],
#        [0.47597305, 1.        ]])

# %%
import platform #os 정보를 가져 올 수 있는 모듈
from matplotlib import font_manager, rc # font_manager : 폰트 관리 모듈, rc : 폰트 변경 모듈
from matplotlib import pyplot as plt # 시각화 도구
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False # 유니코드 표현 설정하기

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # OS가 APPLE(Darwin)이면 AppleGothic으로 폰트 설정
elif platform.system() == 'Windows':
    path="c:/Windows/Fonts/malgun.ttf" #OS가 윈도우즈면 맑은 고딕으로 설정
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown System.')

# %%
plt.figure(figsize=(6,6))
plt.scatter(data_result['랭킹'], data_result['멜론_동영상_랭킹'], s=50)
plt.xlabel('일간_랭킹')
plt.ylabel('동영상_랭킹')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(data_result['랭킹'], data_result['멜론_동영상_랭킹'], 1)
fp1
# Out:
# array([ 0.39213411, 20.66688283])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(0, 100, 100)
plt.figure(figsize=(10,10))
plt.scatter(data_result['랭킹'], data_result['멜론_동영상_랭킹'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('일간_랭킹')
plt.ylabel('동영상_랭킹')
plt.grid()
plt.show()
